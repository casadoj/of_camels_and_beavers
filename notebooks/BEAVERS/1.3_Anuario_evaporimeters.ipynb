# %% [markdown]
# # *Anuario de aforos*: evaporimeters
# ***

# %%
import pandas as pd
import geopandas as gpd

from camels_es.config import Config
from camels_es.anuario_aforos import extraer_evaporimetros

# %% [markdown]
# ## Configuration

# %%
cfg = Config('../config_BEAVER.yml')

# %% [markdown]
# ## Evaporimeters

# %%
# identificar demarcaciones hidrográficas
basins = {
    dir.stem: dir for dir in cfg.path_records.iterdir() 
    if dir.is_dir() &  (dir.stem not in ['estaciones', 'GIS', 'timeseries'])
    }

# %%
for basin, path in basins.items():
    break

# %%
# extraer estaciones evaporimétricas

stations = extraer_evaporimetros(cfg.path_in / cuenca / 'estev.csv')

# %%
pd.read_csv(
    cfg.path_in / cuenca / 'evap.csv',
    sep=';',
    index_col='ref_evap'
)
